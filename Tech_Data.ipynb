# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Tech_Data = pd.read_excel(r"c:\Users\ebunope.ajayi\OneDrive - IBEDC\Desktop\IBEDC 2025\TECH DATA FOLDER FROM PRECIOUS SYSTEM\TECH DATA\TECHNICAL DATA\TECHNICAL DATA.xlsx")
Tech_Data.fillna("NULL", inplace=True)

# %%
pd.set_option("display.max_columns", None)

# %%
Tech_Data.columns
# Out:
# Index(['Asset ID', 'Asset Type', 'Left', 'Top', 'Latitude', 'Longtitude',
#        'Nac Code', 'X_image', 'Y_image', 'Capture_DateTime', 'Synced_DateTime',
#        'Queried', 'Queried_Date', 'Queried_Comment', 'Queried_By', 'Verified',
#        'Verified_DateTime', 'Verified_By', 'DSS_Parent', 'DSS_Owner',
#        'DSS_Name', 'DSS_Address', 'DSS_Rating', 'DSS_Make',
#        'DSS_Feederpillar_Type', 'DSS_Condition', 'DSS_Catridge', 'DSS_HV_Fuse',
#        'DSS_HV_Fuse_Condition', 'DSS_Lightning_Arrester', 'DSS_Serial_No',
#        'DSS_Voltage_Ratio', 'DSS_Oil_Temp', 'DSS_Winding_Temp',
#        'DSS_Manufacture_Year', 'DSS_Installation_Year',
#        'DSS_country_of_Manufacture', 'DSS_Percentage_Loading',
#        'DSS_No_Load_Loss', 'DSS_Load_Loss', 'DSS_Impedence',
#        'DSS_Upriser_Number', 'DSS_Oil_Level', 'DSS_Silica_Condition',
#        'DSS_Security', 'DSS_Substation_gravelled', 'DSS_Substation_vegetation',
# ...

# %%
Kishi_kishi = pd.read_excel(r"C:\Users\ebunope.ajayi\OneDrive - IBEDC\Desktop\IBEDC 2025\TECH DATA FOLDER FROM PRECIOUS SYSTEM\TECH DATA\Duplicated.xlsx", sheet_name="Sheet3")
Kishi_kishi.head()
# Out:
#                      Asset ID                          Asset Type      Left  \
# 0  ACE10210042018424133228638  Distribution Sub Station 11KV_415V  130568.1
# 1   TMP5070202302280943294486  Distribution Sub Station 11KV_415V       NaN
# 2   TMP5070202302280943294694  Distribution Sub Station 11KV_415V       NaN
# 3   TMP5070202302280943293149  Distribution Sub Station 33KV_415V       NaN
# 4  TMP11507020230228094329148  Distribution Sub Station 33KV_415V       NaN
#
#         Top  Latitude  Longtitude     Nac Code   X_image   Y_image  \
# 0 -281733.8  8.166870    4.197520  HBGSD JBT0W  268257.0  250211.0
# 1       NaN  7.329461    3.862821          NaN       NaN       NaN
# 2       NaN  7.329461    3.862821          NaN       NaN       NaN
# 3       NaN  6.898910    3.457264          NaN       NaN       NaN
# 4       NaN  7.858833    4.607717          NaN       NaN       NaN
#
#   Capture_DateTime  ...   Bhub_Name  Region  Status  DSS_MeterNo  \
# ...

# %%
dp = Tech_Data[Tech_Data["Asset ID"].isin(Duplicated["Asset ID"])].copy()
dp.to_excel(r"C:\Users\ebunope.ajayi\OneDrive - IBEDC\Desktop\IBEDC 2025\TECH DATA FOLDER FROM PRECIOUS SYSTEM\TECH DATA\Duplicated2.xlsx", index=False)

# %%
DUP = Tech_Data[Tech_Data.duplicated(subset="DSS_Name", keep=False)].copy()
DUP.head()
DUP.to_excel(r"C:\Users\ebunope.ajayi\OneDrive - IBEDC\Desktop\IBEDC 2025\TECH DATA FOLDER FROM PRECIOUS SYSTEM\TECH DATA\Duplicated.xlsx", index=False)

# %%
DUP_ASS = Tech_Data[Tech_Data.duplicated(subset="Asset ID", keep=False)].copy()
DUP_ASS.shape
# Out:
# (28, 77)

# %%
Tech_Data["Bhub_Name"] = Tech_Data["Bhub_Name"].str.strip()

# %%
Tech_Data["Bhub_Name"].value_counts()
# Out:
# 32

# %%
Sagamu_data = Tech_Data[Tech_Data["Bhub_Name"] == "SAGAMU"]
Sagamu_data.to_excel(r"C:\Users\ebunope.ajayi\OneDrive - IBEDC\Desktop\IBEDC 2025\TECH DATA FOLDER FROM PRECIOUS SYSTEM\TECH DATA\Sagamu_Tech.xlsx", index=False)

# %%
Tech_Data["DSS_Rating"].describe()
# Out:
# count    21213.000000
# mean         0.317755
# std          0.278361
# min          0.020000
# 25%          0.100000
# 50%          0.300000
# 75%          0.500000
# max         10.000000
# Name: DSS_Rating, dtype: float64

# %%
plt.boxplot(Tech_Data["DSS_Rating"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x17984db1bd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x17984d59210>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x17984db3c90>],
#  'medians': [<matplotlib.lines.Line2D at 0x17984d59f90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x17984d58e10>],
#  'means': []}

# %%
Tech_Data[Tech_Data["Asset ID"].isin(["TMP5070202302280943296012"])]
# Out:
#                         Asset ID                          Asset Type  Left  \
# 21150  TMP5070202302280943296012  Distribution Sub Station 11KV_415V  NULL
#
#         Top Latitude Longtitude Nac Code X_image Y_image Capture_DateTime  \
# 21150  NULL  6.94674    3.49717     NULL    NULL    NULL             NULL
#
#       Synced_DateTime Queried Queried_Date Queried_Comment Queried_By  \
# 21150            NULL    NULL         NULL            NULL       NULL
#
#       Verified Verified_DateTime Verified_By DSS_Parent    DSS_Owner  \
# 21150     NULL              NULL        NULL       NULL  OWODE EGBA
#
#             DSS_Name                             DSS_Address  DSS_Rating  \
# 21150  HIS OGN-1021A  GELEODUN ROAD, OWODE EGBA, OGUN STATE.        0.05
#
#       DSS_Make DSS_Feederpillar_Type DSS_Condition DSS_Catridge DSS_HV_Fuse  \
# 21150   MEKSAN      200A CHANGE OVER          Good            0    HRC Fuse
#
#       DSS_HV_Fuse_Condition DSS_Lightning_Arrester DSS_Serial_No  \
# ...

# %%
Tech_Data[Tech_Data["DSS_Rating"] > 10]
# Out:
#                         Asset ID                          Asset Type  Left  \
# 21079  TMP5070202302280943295941  Distribution Sub Station 33KV_415V  NULL
#
#         Top  Latitude Longtitude Nac Code X_image Y_image Capture_DateTime  \
# 21079  NULL  7.847417   4.609743     NULL    NULL    NULL             NULL
#
#       Synced_DateTime Queried Queried_Date Queried_Comment Queried_By  \
# 21079            NULL    NULL         NULL            NULL       NULL
#
#       Verified Verified_DateTime Verified_By DSS_Parent DSS_Owner  \
# 21079     NULL              NULL        NULL       NULL     EWETA
#
#                            DSS_Name                      DSS_Address  \
# 21079  A.G.T WIRE AND NAILS COMPANY  OPP,OLAOLUWA AINA STEEL COMPANY
#
#        DSS_Rating   DSS_Make DSS_Feederpillar_Type DSS_Condition DSS_Catridge  \
# 21079       500.0  ASTOR A.S            800A/4WAYS          GOOD         GOOD
#
# ...

# %%
query = pd.read_excel(r"C:\Users\ebunope.ajayi\OneDrive - IBEDC\Desktop\IBEDC 2025\TECH DATA FOLDER FROM PRECIOUS SYSTEM\TECH DATA\Copy of Holistic review_ AS AT 25-07-2025.xlsx")
query.head()
# Out:
#              Tech_DSS_Asset ID                    Tech_DSS_Asset Name  \
# 0   ACE10203082017124113149125                                OKE OBA
# 1   ACE10209452018519133726328                               AL-HALAB
# 2    TMP5070202302280943295238  Ogoolwa Block Indusry (HIS_KWA_1002B)
# 3    ACE1020807201995141259156                          AJOKE ARAROMI
# 4  ACE102039820171214151926799                     NEW GLORY CRESCENT
#
#                         Ecmi Feeder    Ecmi Feeder NAME  \
# 0           ACE10203082017112857347  ERUWA LANLATE 33KV
# 1         ACE1020311201844102847853   KISHI/IGBETI 33KV
# 2         ACE1020311201843163725988           OTTE 33KV
# 3  TMP10400162023031411440161361249           JOJU 33KV
# 4  TMP10400162023031411440161361249           JOJU 33KV
#
#                      Tech_Feeder_ID                       Unnamed: 5  \
# 0       TMP104001620230207122220350    ERUWA LANLATE_ERUWA TOWN 33KV
# ...

# %%
in_data = pd.DataFrame(columns=Tech_Data.columns)
for items in query["Tech_DSS_Asset ID"]:
    if items in Tech_Data["Asset ID"].values:
        in_data = pd.concat([Tech_Data[Tech_Data["Asset ID"] == items], in_data])

in_data.fillna("NULL", inplace=True)
in_data.drop("Unnamed: 77", axis=1, inplace=True)
in_data.head()
# Out:
#                          Asset ID                          Asset Type  \
# 14975   TMP5070202302280943293213  Distribution Sub Station 11KV_415V
# 14974   TMP5070202302280943292778  Distribution Sub Station 11KV_415V
# 14973   TMP5070202302280943293212  Distribution Sub Station 11KV_415V
# 14972  IBE10503702022101323532934  Distribution Sub Station 11KV_415V
# 14971  ACE10204962017127144435758  Distribution Sub Station 11KV_415V
#
#            Left       Top  Latitude Longtitude     Nac Code X_image Y_image  \
# 14975      NULL      NULL  6.969557   3.817035         NULL    NULL    NULL
# 14974      NULL      NULL  7.022411   3.807186         NULL    NULL    NULL
# 14973      NULL      NULL  6.969728   3.816829         NULL    NULL    NULL
# 14972         0         0   6.94363    3.85678  H9M7Q J4PJB       0       0
# 14971 -4593.005  179190.5  6.939929   3.834988  H9KLP J4NZN  267729  252012
#
#       Capture_DateTime  ...  Bhub_Name Region  Status DSS_MeterNo  \
# ...

# %%
in_data2 = Tech_Data[Tech_Data["Asset ID"].isin(query["Tech_DSS_Asset ID"])].copy()
in_data2.head()
# Out:
#                          Asset ID                          Asset Type  \
# 2764   ACE10203412017102595728296  Distribution Sub Station 11KV_415V
# 2765  ACE102034120171025105522853  Distribution Sub Station 11KV_415V
# 2766   ACE10203412017102410319339  Distribution Sub Station 11KV_415V
# 2767  ACE102034120171025102843727  Distribution Sub Station 11KV_415V
# 2768    IBE1050420202210794837903  Distribution Sub Station 11KV_415V
#
#           Left       Top Latitude Longtitude     Nac Code X_image Y_image  \
# 2764  17190.02 -4184.116  7.42791    3.89347  H9Q05 J7467  267814  251295
# 2765  17369.46 -4188.196  7.42807     3.8939  H9Q18 J7469  267814  251295
# 2766  16219.71 -3702.035  7.42678    3.89081  H9PS9 J740G  267810  251297
# 2767  17569.73 -4187.037  7.42819    3.89437  H9Q2G J7468  267815  251295
# 2768         0         0  7.42686    3.89063  H9PRW J740V       0       0
#
#      Capture_DateTime Synced_DateTime Queried Queried_Date Queried_Comment  \
# ...

# %%
import re

# %%
in_data2.to_excel(r"C:\Users\ebunope.ajayi\OneDrive - IBEDC\Desktop\IBEDC 2025\TECH DATA FOLDER FROM PRECIOUS SYSTEM\TECH DATA\Billing_Discrepciances.xlsx", index=False)

# %%
for feeder in in_data2["Feeder_Name"]:
    fd = in_data2[in_data2["Feeder_Name"] == feeder]
    # Clean invalid filename characters
    safe_feeder = re.sub(r'[\\/*?:"<>|]', "_", feeder)
    fd.to_excel(rf"C:\Users\ebunope.ajayi\OneDrive - IBEDC\Desktop\IBEDC 2025\TECH DATA FOLDER FROM PRECIOUS SYSTEM\TECH DATA\Billing_Discrepciances_{safe_feeder}.xlsx", index=False)

# %%
added_03 = pd.read_excel(r"C:\Users\ebunope.ajayi\OneDrive - IBEDC\Desktop\IBEDC 2025\TECH DATA FOLDER FROM PRECIOUS SYSTEM\TECH DATA\NEWLY ADDED\Copy of 005 BHUB ASSET ID GENERATED 7NOS.xlsx", "NEW REQUESTS 33_0.415KV")

# %%
Tech_data_25_07 = pd.read_excel()

# %%
added_03
# Out:
#                     Asset ID                          Asset Type  Left  Top  \
# 0  TMP5070202302280943296035  Distribution Sub Station 33KV_415V   NaN  NaN
# 1  TMP5070202302280943296036  Distribution Sub Station 33KV_415V   NaN  NaN
# 2  TMP5070202302280943296037  Distribution Sub Station 33KV_415V   NaN  NaN
# 3  TMP5070202302280943296038  Distribution Sub Station 33KV_415V   NaN  NaN
# 4  TMP5070202302280943296039  Distribution Sub Station 33KV_415V   NaN  NaN
# 5  TMP5070202302280943296040  Distribution Sub Station 33KV_415V   NaN  NaN
# 6  TMP5070202302280943296041  Distribution Sub Station 11KV_415V   NaN  NaN
#
#    Latitude  Longtitude  Nac Code  X_image  Y_image     Capture_DateTime  ...  \
# 0  6.859686    3.912502       NaN      NaN      NaN  2025-02-06 00:00:00  ...
# 1  6.722456    3.965959       NaN      NaN      NaN  2025-02-06 00:00:00  ...
# 2  7.360617    3.989591       NaN      NaN      NaN                  NaN  ...
# ...

# %%
in_data = pd.DataFrame(columns=Tech_Data.columns)
for items in added_03["Asset ID"]:
    if items in Tech_Data["Asset ID"].values:
        in_data = pd.concat([Tech_Data[Tech_Data["Asset ID"] == items], in_data])
in_data
# Out:
# Empty DataFrame
# ...

# %%
#Validate Feeder Names
feede = pd.DataFrame(columns=Tech_Data.columns)
for IDs in added_03["Feeder_ID"]:
    feede = pd.concat([Tech_Data[Tech_Data["Feeder_ID"] == IDs], feede])
feede.head()
# Out:
#                           Asset ID                          Asset Type  \
# 4204   ACE102080720191031114326891  Distribution Sub Station 11KV_415V
# 4214     IBE1050345202281614741545  Distribution Sub Station 11KV_415V
# 14613   ACE10207712018322104056912  Distribution Sub Station 11KV_415V
# 14614     ACE102077120183221194567  Distribution Sub Station 11KV_415V
# 14615   ACE10207712018322122137434  Distribution Sub Station 11KV_415V
#
#            Left       Top  Latitude Longtitude     Nac Code X_image Y_image  \
# 4204    1682491  -2889413  7.725971   4.512871  HC8FT J8LZ1  268716  250857
# 4214        NaN       NaN  7.725924   4.520734          NaN     NaN     NaN
# 14613    256982 -131328.7  7.766063   4.536566  HCB7B J8SZ7  268750  250798
# 14614  257100.2 -130909.2  7.764953   4.536886  HCB81 J8SS7  268751  250800
# 14615  256433.7   -131016  7.765233   4.535096  HCB40 J8STH  268748  250799
#
#       Capture_DateTime  ... Bhub_Name Region  Status DSS_MeterNo  \
# ...

# %%
feede["Feeder_Name"].value_counts()
# Out:
# Feeder_Name
# SANGO 33KV               226
# GBONGAN ROAD 11KV        130
# IDOWA 33KV_IKEN OGBO      94
# NBL 33KV_ADEGBAYI         91
# POWERLINE 33KV _OSBC      72
# IJEBU-IGBO 33KV           40
# OSOGBO/IKIRUN 33KV        38
# SANGO 33KV                 7
# IJEBU-IGBO 33KV            3
# GBONGAN ROAD 11KV          2
# OSOGBO/IKIRUN              2
# OSOGBO/IKIRUN 33KV         1
# Name: count, dtype: int64

# %%
Tech_Data = pd.concat([Tech_Data, added_03])
Tech_Data.to_excel(r"C:\Users\ebunope.ajayi\OneDrive - IBEDC\Desktop\IBEDC 2025\TECH DATA FOLDER FROM PRECIOUS SYSTEM\TECH DATA\TECHNICAL DATA\TECHNICAL DATA - Copy.xlsx")

# %%
Tech_Data['Bhub_Name'].value_counts().tail(10)
# Out:
# Bhub_Name
# SAGAMU       50
# Ede          44
# APATA        14
# Omuaran       5
# ILESA         4
# Challenge     3
# SANGO         2
# ILE-IFE       1
# Osogbo        1
# Molete        1
# Name: count, dtype: int64

# %%
feeders_id = pd.read_excel(r"C:\Users\ebunope.ajayi\OneDrive - IBEDC\Desktop\IBEDC 2025\TECH DATA FOLDER FROM PRECIOUS SYSTEM\TECH DATA\TECHNICAL DATA AS AT\2025\AUG 2025\TECHNICAL DATA AS AT 06-08-2025.xlsx", "Sheet5")

# %%
#Tech_Data.loc[["caste_household"] == caste, "caste_household"]
Tech_Data2 = pd.read_excel(r"C:\Users\ebunope.ajayi\OneDrive - IBEDC\Desktop\IBEDC 2025\TECH DATA FOLDER FROM PRECIOUS SYSTEM\TECH DATA\TECHNICAL DATA AS AT\2025\AUG 2025\TECHNICAL DATA AS AT 06-08-2025.xlsx")

# %%
feeders_id.head()
# Out:
#              Feeder_Name                         Feeder_ID
# 0  192 , OWODE YEWA 11KV       ACE102039920171126151216107
# 1               7UP 11KV       ACE102033020171014115859230
# 2       AARTI STEEL 33KV  TMP10400162023031411440161361178
# 3             ABEBI 11KV        ACE10203792017128132254824
# 4       ABEOKUTA RD 11KV        ACE10203792017112710512871

# %%
result = feeders_id.merge(Tech_Data2[['Feeder_ID', 'Bhub_Name']], on="Feeder_ID", how='inner')
result = result.drop_duplicates('Feeder_ID')
result.head()
# Out:
#               Feeder_Name                         Feeder_ID Bhub_Name
# 0   192 , OWODE YEWA 11KV       ACE102039920171126151216107       OTA
# 2                7UP 11KV       ACE102033020171014115859230    MOLETE
# 41       AARTI STEEL 33KV  TMP10400162023031411440161361178       OTA
# 43             ABEBI 11KV        ACE10203792017128132254824     SANGO
# 91       ABEOKUTA RD 11KV        ACE10203792017112710512871     SANGO

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 522 entries, 0 to 21345
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Feeder_Name  521 non-null    object
#  1   Feeder_ID    521 non-null    object
#  2   Bhub_Name    522 non-null    object
# dtypes: object(3)
# memory usage: 16.3+ KB

# %%
result.to_excel(r"C:\Users\ebunope.ajayi\OneDrive - IBEDC\Desktop\IBEDC 2025\TECH DATA FOLDER FROM PRECIOUS SYSTEM\TECH DATA\Feeder_Bhub.xlsx", index=False)
