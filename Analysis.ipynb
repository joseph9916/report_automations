# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
Tech_Data = pd.read_excel(r"c:\Users\ebunope.ajayi\OneDrive - IBEDC\Desktop\IBEDC 2025\TECH DATA FOLDER FROM PRECIOUS SYSTEM\TECH DATA\TECHNICAL DATA\TECHNICAL DATA.xlsx")

# %%
Tech_Data.head()
# Out:
#                      Asset ID                          Asset Type      Left  \
# 0    TMP113020230314120517373  Distribution Sub Station 33KV_415V       NaN
# 1  ACE10203602017111785515937  Distribution Sub Station 11KV_415V  21110.36
# 2   ACE1020689201982714250370  Distribution Sub Station 11KV_415V   1455927
# 3  ACE10211462019710102017809  Distribution Sub Station 11KV_415V   1457122
# 4  ACE10203602017111410417499  Distribution Sub Station 11KV_415V  19894.43
#
#         Top  Latitude Longtitude     Nac Code X_image Y_image  \
# 0       NaN  8.406265   4.603352          NaN     NaN     NaN
# 1  9320.323   7.39211    3.90393  H9QRT J6XSG  267829  251348
# 2  -2764899   7.39539    3.90513  H9QVJ J6Z97  267831  251343
# 3  -2764311  7.393826   3.908333  H9R3Q J6Z26  267835  251345
# 4  10178.14   7.38982    3.90067  H9QJH J6XG6  267824  251351
#
#   Capture_DateTime  ...  Bhub_Name  Region  Status DSS_MeterNo DSS_Local_Govt  \
# 0              NaN  ...  CHALLENGE   KWARA  ACTIVE         NaN       IFELODUN
# 1         0.010382  ...      DUGBE  IBADAN  ACTIVE         NaN   IBADAN NORTH
# 2         0.028958  ...      DUGBE  IBADAN  ACTIVE         NaN   IBADAN NORTH
# 3         0.036516  ...      DUGBE  IBADAN  ACTIVE         NaN   IBADAN NORTH
# 4         0.036435  ...      DUGBE  IBADAN  ACTIVE         NaN   IBADAN NORTH
#
#   DSS_State DSS_Comment  Feeder_Name                      Feeder_ID  \
# 0     KWARA      ACTIVE     YSR 33KV  TMP10400162023031411440161319
# 1       OYO      ACTIVE  YEMETU 11KV      ACE1020516201868111343824
# 2       OYO      ACTIVE  YEMETU 11KV      ACE1020516201868111343824
# 3       OYO      ACTIVE  YEMETU 11KV      ACE1020516201868111343824
# 4       OYO      ACTIVE  YEMETU 11KV      ACE1020516201868111343824
#
#   Feeder_Band
# 0        A20H
# 1        C12H
# 2        C12H
# 3        C12H
# 4        C12H
#
# [5 rows x 77 columns]

# %%
No_of_DT_per_Region = Tech_Data["Region"].value_counts()
#No_of_DT_per_Region.to_excel("Region Analysis")

# %%
No_of_DT_per_Region.plot(kind="bar")
plt.xlabel("Region")
# Out:
# <AxesSubplot: xlabel='Region'>
